# %%
import spacy
import nltk
import wordcloud
import langdetect
import textblob
# Data management
import os

import statistics as st

import json
import requests
import pyjsonviewer

from functools import reduce
import operator

import pandas as pd
import numpy as np

import lyricsgenius
from lyrics_extractor import SongLyrics

from dotenv import load_dotenv
load_dotenv()

# Databases
import sqlalchemy as alch
from getpass import getpass
from pymongo import MongoClient

# Languages
import re

import spacy
import es_core_news_sm
import en_core_web_sm

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords


from wordcloud import WordCloud
from langdetect import detect
from textblob import TextBlob

# Visualization
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
spotify_id = "836aa91c1a7a4dee9b76354346169d33"
spotify_secret = "6b85b8ce8c4f46b8876afef17870edb0"
url = "localhost:27017"
sql_pw = "password"

# %%
client_id= os.getenv("spotify_id")
client_secret= os.getenv("spotify_secret")

# %%
body_params = {"grant_type":"client_credentials"}

# %%
url = "https://accounts.spotify.com/api/token"

# %%
response = requests.post(url, data=body_params, auth=(client_id, client_secret), verify=True)
response.content
# Out:
# b'{"access_token":"BQBcMiDo3Pmdo6THVB5mOoEafJ0p9k8KmYZ-VIeNRVo7s8H7AuZZRMLHbuUgz8jSTOg81URenaMIgdYyF8zCpIvWQmnmlIW49DiohPvyISoZZMlzXsg","token_type":"Bearer","expires_in":3600}'

# %%
token = response.json()["access_token"]

# %%
def get_token():
    CLIENT_ID=os.getenv("client_id")
    CLIENT_SECRET=os.getenv("client_secret")
    body_params = {"grant_type":"client_credentials"}
    url = "https://accounts.spotify.com/api/token"
    response = requests.post(url, data=body_params, auth=(client_id, client_secret), verify=True)
    token = response.json()["access_token"]
        
    return token

# %%
token = get_token()
token
# Out:
# 'BQA7W51NLUanpy_teIuDf_8Vk-2OcdzMwDKFUoYBh7LNyr3mxjCnF9V1TPa7Mh6TySnvpbOyMmPjtYFrq2hrCduinfEt4hDMnvonEvKaedwbdWHcCJg'

# %%
file = open (".env",'a') #w will overwrite and a will append

# %%
file.write(f"\n spotify_token={token}")
# Out:
# 131

# %%
file.close()

# %%
def save_token():
    file = open ('.env','a')
    f = open ('.env','r')
    file.write("\n")
    file.write(f"spotify_token={token}")
    file.close() 
    return (f.read())

# %%
save_token()
# Out:
# 'spotify_id = "836aa91c1a7a4dee9b76354346169d33"\nspotify_secret = "6b85b8ce8c4f46b8876afef17870edb0"\nurl = "localhost:27017"\nsql_pw = "password"\nGCS_ENGINE_ID = "c69319065a84c4879"\nGCS_API_KEY = "AIzaSyDN3gzl1dPYu3q3QX6BRSaP58ywxvSOhIY"\ngenius_id = "AGqkHpB5D2C3FlAWD2FNVkijuLEqc2G0eGiKe8Ns-xC0PeSGxzCyS2rTzh7DwLn8"\ngenius_secret = "PNypCIRP_hvspYP90SHOCovGjLOoaSxruZptoLLyjYN6fXgZzY3LduLS2hPCKLwtyxtRsc8brbs4LKHF8jZEyQ"\ngenius_token = "WWwFPfIOkN0Kvot69_bmhtYUZxNQDtPkj_4EEewLnZHZ9KSARmWVj0ifu3E0m7Fk"\nspotify_token="BQDtFzZMoDdeaJP3GZIIUaRVOq0F_gpyGktx1C9skgvehLj6UycPxVmrrxddMa82oCXmtYsI6i2l8ZRvcBBJP0rAc-sUFurTumZb-AzlBk09aF4kw_g"\n\n spotify_token=BQCeCyKbh5EYsnyaa9PEXm4B9RKmucyBsgbIIOJSK70qSMTgjrejy2qN5EFHc2kSDXAG7PJTIytGc8Rj_fyKYturYOAzLIN1wyAiCVS9-80sZTwybxA\nspotify_token=BQCeCyKbh5EYsnyaa9PEXm4B9RKmucyBsgbIIOJSK70qSMTgjrejy2qN5EFHc2kSDXAG7PJTIytGc8Rj_fyKYturYOAzLIN1wyAiCVS9-80sZTwybxA\n spotify_token=BQD4k1-XlLW4-UimHJPuMtCHLz2xEb_5l-B48MaMWI8uROqfbFNGJjuq-zzG5qvOXN2nKMM8b84YjSQCY-nhjY0lQtz4KHOX38oEvP4jEe30m1WhMKY\nspotify_token=BQD4k1-XlLW4-UimHJPuMtCHLz2xEb_5l-B48MaMWI8uROqfbFNGJjuq-zzG5qvOXN2nKMM8b84YjSQCY-nhjY0lQtz4KHOX38oEvP4jEe30m1WhMKY\n spotify_token=BQA7W51NLUanpy_teIuDf_8Vk-2OcdzMwDKFUoYBh7LNyr3mxjCnF9V1TPa7Mh6TySnvpbOyMmPjtYFrq2hrCduinfEt4hDMnvonEvKaedwbdWHcCJg\nspotify_token=BQA7W51NLUanpy_teIuDf_8Vk-2OcdzMwDKFUoYBh7LNyr3mxjCnF9V1TPa7Mh6TySnvpbOyMmPjtYFrq2hrCduinfEt4hDMnvonEvKaedwbdWHcCJg'

# %%
headers = {"Authorization":f"Bearer {token}"}

# %%
url_base = "https://api.spotify.com/v1/playlists/"

# %%
straight_vibin = "https://open.spotify.com/playlist/62aap5B2EcMMcQ3DWNoB6L?si=d0aac11c29874614"

# %%
mmmm = "https://open.spotify.com/playlist/2oJXsocS17seGF29iYq2IT?si=8463cc37cd17439a"

# %%
stink = "https://open.spotify.com/playlist/3url7nbrfKDeNW8Xm3QOb5?si=b99948a3c4574992"

# %%
dysphoria = "https://open.spotify.com/playlist/5dhSNCF1Gn0vMQEDLEUXcU?si=f4cdd36799904682"

# %%
nostalgia = "https://open.spotify.com/playlist/0WrD7hV1xnhqiPhNXNYWU3?si=5310902542044e62"

# %%
vibinid = straight_vibin.split("/")[4].split("?")[0]
mmmmid = mmmm.split("/")[4].split("?")[0]
stinkid = stink.split("/")[4].split("?")[0]
dysphoriaid = dysphoria.split("/")[4].split("?")[0]
nostalgiaid = nostalgia.split("/")[4].split("?")[0]

# %%
query2 = url_base + vibinid
query3 = url_base + mmmmid
query4 = url_base + stinkid
query5 = url_base + dysphoriaid
query6 = url_base + nostalgiaid

# %%
response2 = requests.get(query2, headers=headers).json()
response3 = requests.get(query3, headers=headers).json()
response4 = requests.get(query4, headers=headers).json()
response5 = requests.get(query5, headers=headers).json()
response6 = requests.get(query6, headers=headers).json()

# %%
def getFromDict(dicto,songs):
    return reduce(operator.getitem,songs,dicto)

# %%
def extractspotify (json):
    ply = {"Playlist": ["name"],"Playlist ID": ["id"],}
    songs = {"Name": ["track", "name"], "User": ["added_by", "id"]}
    total = []
    for element in json["tracks"]["items"]:
        track = {key:getFromDict(element, value) for key, value in songs.items()}
        artists = getFromDict(element, ["track", "artists"])
        track["Artist"] = [dicto["name"] for dicto in artists]
        track.update({key: getFromDict(json, value) for key,value in ply.items()})
        total.append(track)
    return total

# %%
my_songs2 = extractspotify(response2)
my_songs2[0]
# Out:
# {'Name': 'Wandered To LA (with Justin Bieber)',
#  'User': 'qk6itwwnf6xczuzqyl2l3n5hc',
#  'Artist': ['Juice WRLD', 'Justin Bieber'],
#  'Playlist': 'straight vibin',
#  'Playlist ID': '62aap5B2EcMMcQ3DWNoB6L'}

# %%
my_songs3= extractspotify(response3)
my_songs3[0]
# Out:
# {'Name': 'KIDS ON MOLLY',
#  'User': 'qk6itwwnf6xczuzqyl2l3n5hc',
#  'Artist': ['Aries'],
#  'Playlist': 'mmmm',
#  'Playlist ID': '2oJXsocS17seGF29iYq2IT'}

# %%
my_songs4 = extractspotify(response4)
my_songs4[0]
# Out:
# {'Name': 'The Difference',
#  'User': 'qk6itwwnf6xczuzqyl2l3n5hc',
#  'Artist': ['Flume', 'Toro y Moi'],
#  'Playlist': 'stinky',
#  'Playlist ID': '3url7nbrfKDeNW8Xm3QOb5'}

# %%
my_songs5 = extractspotify(response5)
my_songs5[0]
# Out:
# {'Name': 'Downhill',
#  'User': 'qk6itwwnf6xczuzqyl2l3n5hc',
#  'Artist': ['Lund'],
#  'Playlist': 'Dysphoria ',
#  'Playlist ID': '5dhSNCF1Gn0vMQEDLEUXcU'}

# %%
my_songs6 = extractspotify(response6)
my_songs6[0]
# Out:
# {'Name': 'Crank That (Soulja Boy)',
#  'User': 'qk6itwwnf6xczuzqyl2l3n5hc',
#  'Artist': ['Soulja Boy'],
#  'Playlist': 'Nostalgia',
#  'Playlist ID': '0WrD7hV1xnhqiPhNXNYWU3'}

# %%
df2 = pd.DataFrame(my_songs2)

# %%
df3 = pd.DataFrame(my_songs3)

# %%
df4 = pd.DataFrame(my_songs4)

# %%
df5 = pd.DataFrame(my_songs5)

# %%
df6 = pd.DataFrame(my_songs6)

# %%
users_to_replace = {"qk6itwwnf6xczuzqyl2l3n5hc":"Hassan"}

# %%
df2["User"] = df2.User.replace(users_to_replace)

# %%
df3["User"] = df3.User.replace(users_to_replace)

# %%
df4["User"] = df4.User.replace(users_to_replace)

# %%
df5["User"] = df5.User.replace(users_to_replace)

# %%
df2.sample()
# Out:
#            Name    User                            Artist        Playlist  \
# 6  Bang My Line  Hassan  [Pretty Pacc, 6 Dogs, Luke Wave]  straight vibin
#
#               Playlist ID
# 6  62aap5B2EcMMcQ3DWNoB6L

# %%
df3.sample()
# Out:
#    Name    User                         Artist Playlist  \
# 22  LOL  Hassan  [Melo Makes Music, 916frosty]     mmmm
#
#                Playlist ID
# 22  2oJXsocS17seGF29iYq2IT

# %%
df4.sample()
# Out:
#        Name    User   Artist Playlist             Playlist ID
# 5  SAYONARA  Hassan  [Aries]   stinky  3url7nbrfKDeNW8Xm3QOb5

# %%
df5.sample()
# Out:
#          Name    User        Artist    Playlist             Playlist ID
# 39  New Level  Hassan  [Eli Sostre]  Dysphoria   5dhSNCF1Gn0vMQEDLEUXcU

# %%
all_my_songs = pd.concat([df2,df3,df4,df5,df6])

# %%
all_my_songs.isnull().sum()
# Out:
# Name           0
# User           0
# Artist         0
# Playlist       0
# Playlist ID    0
# dtype: int64

# %%
all_my_songs.sample()
# Out:
#          Name    User              Artist        Playlist  \
# 25  Alienated  Hassan  [sleep.ing, Powfu]  straight vibin
#
#                Playlist ID
# 25  62aap5B2EcMMcQ3DWNoB6L

# %%
load_dotenv()
# Out:
# True

# %%
GCS_ENGINE_ID = os.getenv("GCS_ENGINE_ID")
GCS_API_KEY = os.getenv("GCS_API_KEY")

# %%
extract_lyrics = SongLyrics(GCS_ENGINE_ID , GCS_API_KEY)

# %%
genius_secret = os.getenv("genius_secret")
access_token = os.getenv("genius_token")

# %%
access_token
# Out:
# 'WWwFPfIOkN0Kvot69_bmhtYUZxNQDtPkj_4EEewLnZHZ9KSARmWVj0ifu3E0m7Fk'

# %%
def get_lyrics(artist, song):
    try:
        genius = lyricsgenius.Genius(access_token)
        artist = genius.search_artist(artist[0], max_songs= 1, include_features=True)
        song = artist.song(song)
        return song.lyrics
    
    except:
        return np.nan

# %%
all_my_songs["Lyrics"] = all_my_songs.apply(lambda x: get_lyrics(x["Artist"], x["Name"]), axis=1)
all_my_songs
# Out:
# Searching for songs by Juice WRLD...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Wandered To LA (with Justin Bieber)" by Juice WRLD...
# Done.
# Searching for songs by Juice WRLD...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Doom" by Juice WRLD...
# Done.
# Searching for songs by Juice WRLD...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Not Enough" by Juice WRLD...
# Done.
# Searching for songs by Juice WRLD...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Girl Of My Dreams (with SUGA of BTS)" by Juice WRLD...
# Done.
# Searching for songs by renforshort...
#
# Changing artist name to '​renforshort'
# Song 1: "​i drive me mad"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "wannabe" by ​renforshort...
# Done.
# Searching for songs by renforshort...
#
# Changing artist name to '​renforshort'
# Song 1: "​i drive me mad"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "fuck, i luv my friends" by ​renforshort...
# Done.
# Searching for songs by Pretty Pacc...
#
# Song 1: "Dawg Shit"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Bang My Line" by Pretty Pacc...
# Done.
# Searching for songs by CMTEN...
#
# Song 1: "NEVER MET!"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "NEVER MET! (feat. Glitch Gum)" by CMTEN...
# Done.
# Searching for songs by sammy rash...
#
# Changing artist name to '​sammy rash'
# Song 1: "Lead Me On"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "lead me on" by ​sammy rash...
# Done.
# Searching for songs by Daniyel...
#
# Song 1: "LOST ONES"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "IT'S OK" by Daniyel...
# Done.
# Searching for songs by tsubi club...
#
# Changing artist name to '​​tsubi club'
# Song 1: "​burbank house"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "burbank house" by ​​tsubi club...
# Done.
# Searching for songs by 44phantom...
#
# Song 1: "Poison"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I WON'T COMPLAIN (feat. Tom The Mail Man)" by 44phantom...
# Done.
# Searching for songs by Zac Greer...
#
# Song 1: "​crazy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "crazy" by Zac Greer...
# Done.
# Searching for songs by Nicky Youre...
#
# Song 1: "Sex and Lemonade"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sunroof" by Nicky Youre...
# Done.
# Searching for songs by iann dior...
#
# Changing artist name to '​iann dior'
# Song 1: "Mood"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "let you" by ​iann dior...
# Done.
# Searching for songs by Oliver Tree...
#
# Song 1: "Alien Boy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Life Goes On (feat. Trippie Redd & Ski Mask The Slump God)" by Oliver Tree...
# Done.
# Searching for songs by Christian French...
#
# Song 1: "​head first"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "OH WELL" by Christian French...
# Done.
# Searching for songs by 24kGoldn...
#
# Song 1: "Mood"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "More Than Friends" by 24kGoldn...
# Done.
# Searching for songs by Justus Bennetts...
#
# Song 1: "Bad Day"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cool Kids" by Justus Bennetts...
# Done.
# Searching for songs by Tommy Ice...
#
# Song 1: "Forever"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "hurt myself" by Tommy Ice...
# Done.
# Searching for songs by sammy rash...
#
# Changing artist name to '​sammy rash'
# Song 1: "Lead Me On"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "best friends" by ​sammy rash...
# Done.
# Searching for songs by Landon Cube...
#
# Song 1: "Red Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Down & Out" by Landon Cube...
# Done.
# Searching for songs by remy...
#
# Changing artist name to 'Monty'
# Song 1: "679"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "he's not your boyfriend, he's your boy friend" by Monty...
# Done.
# Searching for songs by Nic D...
#
# Song 1: "Fine Apple"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Icee Pop" by Nic D...
# Done.
# Searching for songs by Weston Estate...
#
# Song 1: "Hypnotized"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Stoked" by Weston Estate...
# Done.
# Searching for songs by sleep.ing...
#
# Changing artist name to 'Sleeping At Last'
# Song 1: "Saturn"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Alienated" by Sleeping At Last...
# Done.
# Searching for songs by YOG$...
#
# Song 1: "Set It Off"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Overload" by YOG$...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "BOUNTY HUNTER" by Aries...
# Done.
# Searching for songs by Tai Verdes...
#
# Song 1: "A-O-K"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Let's go to Hell" by Tai Verdes...
# Done.
# Searching for songs by Ollie...
#
# Song 1: "Fading Away"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Speed Limit" by Ollie...
# Done.
# Searching for songs by SEB...
#
# Changing artist name to 'Kesha'
# Song 1: "Praying"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "god of the sunsets" by Kesha...
# Done.
# Searching for songs by Rence...
#
# Song 1: "Baby Blue"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Track Shoes" by Rence...
# Done.
# Searching for songs by Landon Cube...
#
# Song 1: "Red Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Secrets" by Landon Cube...
# Done.
# Searching for songs by sammy rash...
#
# Changing artist name to '​sammy rash'
# Song 1: "Lead Me On"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "summer&cigarettes" by ​sammy rash...
# Done.
# Searching for songs by dempsey hope...
#
# Changing artist name to '​dempsey hope'
# Song 1: "​time flies"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "time flies" by ​dempsey hope...
# Done.
# Searching for songs by G-Eazy...
#
# Song 1: "No Limit"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Faithful (feat. Marc E. Bassy)" by G-Eazy...
# Done.
# Searching for songs by Zachary Knowles...
#
# Song 1: "‌slow down my thoughts"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "stranger to me" by Zachary Knowles...
# Done.
# Searching for songs by Quinn XCII...
#
# Song 1: "Another Day in Paradise"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Mexico City" by Quinn XCII...
# Done.
# Searching for songs by Dennis Lloyd...
#
# Song 1: "Nevermind"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Never Go Back" by Dennis Lloyd...
# Done.
# Searching for songs by Zachary Knowles...
#
# Song 1: "‌slow down my thoughts"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "dancing in the kitchen" by Zachary Knowles...
# Done.
# Searching for songs by Lauren Sanderson...
#
# Song 1: "Written In The Stars"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "17" by Lauren Sanderson...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "KIDS ON MOLLY" by Aries...
# Done.
# Searching for songs by glaive...
#
# Changing artist name to '​glaive'
# Song 1: "​astrid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "1984" by ​glaive...
# Done.
# Searching for songs by glaive...
#
# Changing artist name to '​glaive'
# Song 1: "​astrid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "fuck this town" by ​glaive...
# Done.
# Searching for songs by SAIAH...
#
# Song 1: "Polaroid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cheater (feat. Tom The Mail Man)" by SAIAH...
# Done.
# Searching for songs by Global Dan...
#
# Song 1: "Off-White"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Toxicity" by Global Dan...
# Done.
# Searching for songs by Pretty Pacc...
#
# Song 1: "Dawg Shit"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by YOG$...
#
# Song 1: "Set It Off"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Someday" by YOG$...
# Done.
# Searching for songs by ericdoa...
#
# Changing artist name to '​ericdoa'
# Song 1: "​movinglikeazombie (remix)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "fantasize" by ​ericdoa...
# Done.
# Searching for songs by Ramzoid...
#
# Song 1: "For You"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "9 LIVES" by Ramzoid...
# Done.
# Searching for songs by iamjakehill...
#
# Changing artist name to '​iamjakehill'
# Song 1: "Die a King"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "hate me" by ​iamjakehill...
# Done.
# Searching for songs by Brasstracks...
#
# Song 1: "No Problem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Summertime 1, 2" by Brasstracks...
# Done.
# Searching for songs by Lxst...
#
# Song 1: "Exhausted"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Selfish" by Lxst...
# Done.
# Searching for songs by midwxst...
#
# Changing artist name to '​midwxst'
# Song 1: "RED"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Made It Back" by ​midwxst...
# Done.
# Searching for songs by aldn...
#
# Changing artist name to '​aldn'
# Song 1: "‎glittr"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "dog eat dog" by ​aldn...
# Done.
# Searching for songs by MASN...
#
# Song 1: "Hate Me!"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Don't Talk" by MASN...
# Done.
# Searching for songs by 404vincent...
#
# Song 1: "Fuck School!"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Pisces" by 404vincent...
# Done.
# Searching for songs by Jutes...
#
# Song 1: "Cocaine Cinderella"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Here We Go Again" by Jutes...
# Done.
# Searching for songs by Roderick Porter...
#
# Song 1: "I didn’t realize how empty my bed was until you left"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "THOUGHT OF YOU (feat. Landstrip Chip)" by Roderick Porter...
# Done.
# Searching for songs by Jay Kim...
#
# Song 1: "BELL PEPPER HATE CYPHER"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "complicated" by Jay Kim...
# Done.
# Searching for songs by iamjakehill...
#
# Changing artist name to '​iamjakehill'
# Song 1: "Die a King"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "nerve" by ​iamjakehill...
# Done.
# Searching for songs by Josh A...
#
# Song 1: "Pain"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "CALIFORNIA" by Josh A...
# Done.
# Searching for songs by LIL DUSTY G...
#
# Song 1: "INSECTS"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "One Of A Kind" by LIL DUSTY G...
# Done.
# Searching for songs by Melo Makes Music...
#
# Song 1: "Sleepless"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "LOL" by Melo Makes Music...
# Done.
# Searching for songs by DIRTYXAN...
#
# Song 1: "SAME FEELINGS"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "MEAN GIRLS" by DIRTYXAN...
# Done.
# Searching for songs by Kevin George...
#
# Song 1: "High Like This"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "All in My Head" by Kevin George...
# Done.
# Searching for songs by Marco Luka...
#
# Song 1: "Paradise"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "get me high" by Marco Luka...
# Done.
# Searching for songs by Powfu...
#
# Song 1: "Dead Eyes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "tinted green (feat. Mila Moon & Jomie)" by Powfu...
# Done.
# Searching for songs by Sueco...
#
# Song 1: "​fast"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Paralyzed" by Sueco...
# Done.
# Searching for songs by Memoria XI...
#
# Song 1: "Stone Cold"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Just Friends" by Memoria XI...
# Done.
# Searching for songs by Yung Pinch...
#
# Song 1: "I Know You"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Difference" by Yung Pinch...
# Done.
# Searching for songs by Koi...
#
# Changing artist name to '​koi'
# Song 1: "​cryin too much"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "rushing" by ​koi...
# Done.
# Searching for songs by glaive...
#
# Changing artist name to '​glaive'
# Song 1: "​astrid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "detest me" by ​glaive...
# Done.
# Searching for songs by DC The Don...
#
# Song 1: "WORST DAY :("
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Notice Me" by DC The Don...
# Done.
# Searching for songs by Baby Keem...
#
# Song 1: "Praise God"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "no sense" by Baby Keem...
# Done.
# Searching for songs by DC The Don...
#
# Song 1: "WORST DAY :("
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Rag3 Kidd" by DC The Don...
# Done.
# Searching for songs by whiterosemoxie...
#
# Changing artist name to '​whiterosemoxie'
# Song 1: "​trix"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "ITACHI (feat. midwxst)" by ​whiterosemoxie...
# Done.
# Searching for songs by MILES...
#
# Changing artist name to 'Lil Yachty'
# Song 1: "​iSpy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "MOSH PIT" by Lil Yachty...
# Done.
# Searching for songs by Yoza...
#
# Song 1: "Problems"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Pretty Lies" by Yoza...
# Done.
# Searching for songs by Powfu...
#
# Song 1: "Dead Eyes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "im used to it" by Powfu...
# Done.
# Searching for songs by Powfu...
#
# Song 1: "Dead Eyes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Laying on my porch while we watch the world end." by Powfu...
# Done.
# Searching for songs by 27CLUB...
#
# Song 1: "Drinking Problem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "fuck you" by 27CLUB...
# Done.
# Searching for songs by bbno$...
#
# Changing artist name to '​bbno$'
# Song 1: "​nursery"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "edamame (feat. Rich Brian)" by ​bbno$...
# Done.
# Searching for songs by ericdoa...
#
# Changing artist name to '​ericdoa'
# Song 1: "​movinglikeazombie (remix)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "back n forth" by ​ericdoa...
# Done.
# Searching for songs by glaive...
#
# Changing artist name to '​glaive'
# Song 1: "​astrid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "icarus" by ​glaive...
# Done.
# Searching for songs by Flume...
#
# Song 1: "Never Be Like You"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "The Difference" by Flume...
# Done.
# Searching for songs by The Jungle Giants...
#
# Song 1: "Used To Be In Love"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Used to Be in Love" by The Jungle Giants...
# Done.
# Searching for songs by The Jungle Giants...
#
# Song 1: "Used To Be In Love"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sending Me Ur Loving" by The Jungle Giants...
# Done.
# Searching for songs by glaive...
#
# Changing artist name to '​glaive'
# Song 1: "​astrid"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "heather" by ​glaive...
# Done.
# Searching for songs by Sycco...
#
# Song 1: "Dribble"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Powfu...
# Song 1: "Dead Eyes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "snowflake (feat. Jaden & Sarcastic Sounds)" by Powfu...
# Done.
# Searching for songs by Powfu...
#
# Song 1: "Dead Eyes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "a castle by the sea" by Powfu...
# Done.
# Searching for songs by Genesis Owusu...
#
# Song 1: "Don’t Need You"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Good Times" by Genesis Owusu...
# Done.
# Searching for songs by Dominic Fike...
#
# Song 1: "3 Nights"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Chicken Tenders" by Dominic Fike...
# Done.
# Searching for songs by Tobiahs...
#
# Song 1: "Cloud 9"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sculpted" by Tobiahs...
# Done.
# Searching for songs by Dominic Fike...
#
# Song 1: "3 Nights"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Vampire" by Dominic Fike...
# Done.
# Searching for songs by Glass Animals...
#
# Song 1: "Heat Waves"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Tokyo Drifting" by Glass Animals...
# Done.
# Searching for songs by Bea Miller...
#
# Song 1: "THE BADDEST"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "FEEL SOMETHING DIFFERENT" by Bea Miller...
# Done.
# Searching for songs by Flume...
#
# Song 1: "Never Be Like You"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Rushing Back" by Flume...
# Done.
# Searching for songs by Cab'Ral...
#
# Changing artist name to 'Spellling'
# Song 1: "Little Deer"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Take Time" by Spellling...
# Done.
# Searching for songs by Kota the Friend...
#
# Song 1: "Colorado"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Long Beach" by Kota the Friend...
# Done.
# Searching for songs by BabyJake...
#
# Song 1: "Cigarettes on Patios"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Head In The Clouds" by BabyJake...
# Done.
# Searching for songs by Young Franco...
#
# Song 1: "Fallin’ Apart"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Juice - Castelle Remix" by Young Franco...
# Done.
# Searching for songs by Baby Keem...
#
# Song 1: "Praise God"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "16" by Baby Keem...
# Done.
# Searching for songs by Glass Animals...
#
# Song 1: "Heat Waves"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Heat Waves (with iann dior)" by Glass Animals...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Downhill" by ℒund...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "BAD NEWS" by Aries...
# Done.
# Searching for songs by Zac Greer...
#
# Song 1: "​crazy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "enemies" by Zac Greer...
# Done.
# Searching for songs by $NOT...
#
# Song 1: "GOSHA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Revenge" by $NOT...
# Done.
# Searching for songs by The Kid LAROI...
#
# Song 1: "WITHOUT YOU"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "SO DONE" by The Kid LAROI...
# Done.
# Searching for songs by Landon Cube...
#
# Song 1: "Red Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Drugs" by Landon Cube...
# Done.
# Searching for songs by Josh A...
#
# Song 1: "Pain"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Worst Mistakes" by Josh A...
# Done.
# Searching for songs by SAINt JHN...
#
# Song 1: "Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sucks To Be You" by SAINt JHN...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Alone" by ℒund...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by convolk...
#
# Changing artist name to '​convolk'
# Song 1: "​lonewolf"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "whatever it takes" by ​convolk...
# Done.
# Searching for songs by SAINt JHN...
#
# Song 1: "Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Wedding Day" by SAINt JHN...
# Done.
# Searching for songs by Joji...
#
# Song 1: "SLOW DANCING IN THE DARK"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Will He" by Joji...
# Done.
# Searching for songs by Khalid...
#
# Song 1: "1-800-273-8255"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Location" by Khalid...
# Done.
# Searching for songs by Juice WRLD...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Hide (feat. Seezyn)" by Juice WRLD...
# Done.
# Searching for songs by Future...
#
# Searching for songs by Joji...
#
# Song 1: "SLOW DANCING IN THE DARK"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sanctuary" by Joji...
# Done.
# Searching for songs by Khalid...
#
# Song 1: "1-800-273-8255"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Therapy" by Khalid...
# Done.
# Searching for songs by Landon Cube...
#
# Song 1: "Red Roses"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Makeup" by Landon Cube...
# Done.
# Searching for songs by Future...
#
# Song 1: "Mask Off"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "My Collection" by Future...
# Done.
# Searching for songs by Future...
#
# Song 1: "Mask Off"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Comin Out Strong (feat. The Weeknd)" by Future...
# Done.
# Searching for songs by Don Toliver...
#
# Song 1: "CAN’T SAY"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Situation" by Don Toliver...
# Done.
# Searching for songs by 6 Dogs...
#
# Song 1: "Faygo Dreams"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Low" by ℒund...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "By My Side" by ℒund...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Fall Away" by ℒund...
# Done.
# Searching for songs by YNW Melly...
#
# Song 1: "Murder on My Mind"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Suicidal (Remix) [feat. Juice WRLD]" by YNW Melly...
# Done.
# Searching for songs by brakence...
#
# Changing artist name to '​brakence'
# Song 1: "​rosier/punk2"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "fuckboy" by ​brakence...
# Done.
# Searching for songs by Lund...
#
# Changing artist name to 'ℒund'
# Song 1: "Broken"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Red Tide" by ℒund...
# Done.
# Searching for songs by danny orange...
#
# Changing artist name to '​danny orange'
# Song 1: "Expensive"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Azizi Gibson...
#
# Song 1: "Smoking with the Gods"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cobra" by Azizi Gibson...
# Done.
# Searching for songs by Jasiah...
#
# Song 1: "Crisis"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "When I'm Gone" by Jasiah...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "RACECAR" by Aries...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "AMY'S GRAVE" by Aries...
# Done.
# Searching for songs by Joji...
#
# Song 1: "SLOW DANCING IN THE DARK"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Pretty Boy (feat. Lil Yachty)" by Joji...
# Done.
# Searching for songs by Brent Faiyaz...
#
# Song 1: "Crew"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Dead Man Walking" by Brent Faiyaz...
# Done.
# Searching for songs by Koi...
#
# Changing artist name to '​koi'
# Song 1: "​cryin too much"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "beverly" by ​koi...
# Done.
# Searching for songs by ...
#
# No results found for ''.
# Searching for songs by The Kid LAROI...
#
# Song 1: "WITHOUT YOU"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "NOT FAIR (feat. Corbin)" by The Kid LAROI...
# Done.
# Searching for songs by Eli Sostre...
#
# Song 1: "Vibe With"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "New Level" by Eli Sostre...
# Done.
# Searching for songs by Joji...
#
# Song 1: "SLOW DANCING IN THE DARK"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "R.I.P. (feat. Trippie Redd)" by Joji...
# Done.
# Searching for songs by Aries...
#
# Song 1: "SAYONARA"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "CAROUSEL" by Aries...
# Done.
# Searching for songs by brakence...
#
# Changing artist name to '​brakence'
# Song 1: "​rosier/punk2"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "rosier/punk2" by ​brakence...
# Done.
# Searching for songs by Reo Cragun...
#
# Song 1: "On My Way"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Last Goodbyes" by Reo Cragun...
# Done.
# Searching for songs by Trippie Redd...
#
# Song 1: "Fuck Love"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Throw It Away" by Trippie Redd...
# Done.
# Searching for songs by XXXTENTACION...
#
# Searching for songs by brakence...
#
# Changing artist name to '​brakence'
# Song 1: "​rosier/punk2"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "dropout" by ​brakence...
# Done.
# Searching for songs by Soulja Boy...
#
# Searching for songs by Jay Sean...
#
# Song 1: "Down"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Soulja Boy...
#
# Song 1: "Crank That (Soulja Boy)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Kiss Me Thru The Phone" by Soulja Boy...
# Done.
# Searching for songs by Labrinth...
#
# Song 1: "Jealous"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Earthquake (feat. Tinie Tempah)" by Labrinth...
# Done.
# Searching for songs by Lupe Fiasco...
#
# Song 1: "Touch the Sky"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "The Show Goes On" by Lupe Fiasco...
# Done.
# Searching for songs by Taio Cruz...
#
# Song 1: "Dynamite"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Break Your Heart" by Taio Cruz...
# Done.
# Searching for songs by Taio Cruz...
#
# Song 1: "Dynamite"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Pitbull...
#
# Searching for songs by Pitbull...
#
# Searching for songs by Far East Movement...
#
# Song 1: "Like A G6"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Dr. Dre...
#
# Song 1: "Godzilla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Kush - Main" by Dr. Dre...
# Done.
# Searching for songs by Pitbull...
#
# Song 1: "Feel This Moment"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "International Love (feat. Chris Brown)" by Pitbull...
# Done.
# Searching for songs by Nelly...
#
# Searching for songs by Rihanna...
#
# Searching for songs by Gym Class Heroes...
#
# Song 1: "Stereo Hearts"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Stereo Hearts (feat. Adam Levine)" by Gym Class Heroes...
# Done.
# Searching for songs by Rihanna...
#
# Song 1: "Work"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Don't Stop The Music" by Rihanna...
# Done.
# Searching for songs by Rihanna...
#
# Song 1: "Work"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Hate That I Love You" by Rihanna...
# Done.
# Searching for songs by Taylor Swift...
#
# Song 1: "All Too Well (10 Minute Version) (Taylor’s Version) [From the Vault]"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "You Belong With Me" by Taylor Swift...
# Done.
# Searching for songs by Rihanna...
#
# Song 1: "Work"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Disturbia" by Rihanna...
# Done.
# Searching for songs by Taylor Swift...
#
# Song 1: "All Too Well (10 Minute Version) (Taylor’s Version) [From the Vault]"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Love Story" by Taylor Swift...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Miss Independent" by Ne-Yo...
# Done.
# Searching for songs by Rihanna...
#
# Song 1: "Work"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Rude Boy" by Rihanna...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "So Sick" by Ne-Yo...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Let Me Love You (Until You Learn To Love Yourself)" by Ne-Yo...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "She Got Her Own" by Ne-Yo...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Don't Make Em Like You" by Ne-Yo...
# Done.
# Searching for songs by Usher...
#
# Song 1: "The Matrimony"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Throwback (feat. Jadakiss)" by Usher...
# Done.
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "California Gurls" by Katy Perry...
# Done.
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "E.T." by Katy Perry...
# Done.
# Searching for songs by LMFAO...
#
# Song 1: "Party Rock Anthem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sexy And I Know It" by LMFAO...
# Done.
# Searching for songs by LMFAO...
#
# Song 1: "Party Rock Anthem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Akon...
#
# Song 1: "Waves"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Lonely" by Akon...
# Done.
# Searching for songs by LMFAO...
#
# Song 1: "Party Rock Anthem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Champagne Showers" by LMFAO...
# Done.
# Searching for songs by Akon...
#
# Song 1: "Waves"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I'm So Paid" by Akon...
# Done.
# Searching for songs by Akon...
#
# Song 1: "Waves"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Smack That" by Akon...
# Done.
# Searching for songs by Plies...
#
# Song 1: "Ran off on da Plug Twice (Ritz Carlton)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Hypnotized (feat. Akon)" by Plies...
# Done.
# Searching for songs by Flo Rida...
#
# Song 1: "Low"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Right Round" by Flo Rida...
# Done.
# Searching for songs by Flo Rida...
#
# Song 1: "Low"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Be on You (feat. Ne-Yo)" by Flo Rida...
# Done.
# Searching for songs by Tinie Tempah...
#
# Song 1: "Girls Like"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Written in the Stars (feat. Eric Turner)" by Tinie Tempah...
# Done.
# Searching for songs by Swedish House Mafia...
#
# Song 1: "Don’t You Worry Child"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Miami 2 Ibiza - Swedish House Mafia vs. Tinie Tempah" by Swedish House Mafia...
# No results found for: 'Miami 2 Ibiza - Swedish House Mafia vs. Tinie Tempah Swedish House Mafia'
# Searching for songs by Jason Derulo...
#
# Song 1: "Swalla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Whatcha Say" by Jason Derulo...
# Done.
# Searching for songs by Tinie Tempah...
#
# Song 1: "Girls Like"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Till I'm Gone (feat. Wiz Khalifa)" by Tinie Tempah...
# Done.
# Searching for songs by Bruno Mars...
#
# Song 1: "LOYALTY."
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Just the Way You Are" by Bruno Mars...
# Done.
# Searching for songs by Bruno Mars...
#
# Song 1: "LOYALTY."
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Marry You" by Bruno Mars...
# Done.
# Searching for songs by Jason Derulo...
#
# Song 1: "Swalla"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "It Girl" by Jason Derulo...
# Done.
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Heartless" by Kanye West...
# Done.
# Searching for songs by Explosion Productions...
#
# Changing artist name to 'Explosion production'
# Song 1: "Comme d’hab"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Run This Town - A Tribute to Jay Z and Rihanna and Kanye West" by Explosion production...
# No results found for: 'Run This Town - A Tribute to Jay Z and Rihanna and Kanye West Explosion production'
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Gold Digger" by Kanye West...
# Done.
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Good Life" by Kanye West...
# Done.
# Searching for songs by Lady Gaga...
#
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Stronger" by Kanye West...
# Done.
# Searching for songs by Lady Gaga...
#
# Searching for songs by Sean Kingston...
#
# Song 1: "Beautiful Girls"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Fire Burning" by Sean Kingston...
# Done.
# Searching for songs by Lady Gaga...
#
# Song 1: "Poker Face"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Born This Way" by Lady Gaga...
# Searching for songs by Sean Kingston...
#
# Song 1: "Beautiful Girls"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Take You There" by Sean Kingston...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Only"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Kiss Kiss (feat. T-Pain)" by Chris Brown...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Only"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Take You Down" by Chris Brown...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Only"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Gimme That Remix featuring Lil' Wayne" by Chris Brown...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Only"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Deuces (feat. Tyga & Kevin McCall)" by Chris Brown...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Only"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I Can Transform Ya (feat. Swizz Beatz & Lil' Wayne)" by Chris Brown...
# Done.
# Searching for songs by Baby Bash...
#
# Song 1: "Suga Suga (So Fly)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cyclone (feat. T-Pain)" by Baby Bash...
# Done.
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Monster" by Kanye West...
# Done.
# Searching for songs by Ne-Yo...
#
# Song 1: "Good Life"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Closer" by Ne-Yo...
# Done.
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Baby By Me (Featuring Ne-Yo)" by 50 Cent...
# Done.
# Searching for songs by Trey Songz...
#
# Song 1: "Can’t Get Enough"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Bottoms Up (feat. Nicki Minaj)" by Trey Songz...
# Done.
# Searching for songs by Wiz Khalifa...
#
# Song 1: "See You Again"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Black and Yellow" by Wiz Khalifa...
# Done.
# Searching for songs by Adele...
#
# Song 1: "Hello"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Rolling in the Deep" by Adele...
# Done.
# Searching for songs by Adele...
#
# Song 1: "Hello"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Skyfall" by Adele...
# Done.
# Searching for songs by Sean Kingston...
#
# Song 1: "Beautiful Girls"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Beat It (feat. Chris Brown & Wiz Khalifa)" by Sean Kingston...
# Done.
# Searching for songs by LMFAO...
#
# Song 1: "Party Rock Anthem"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Justin Bieber...
#
# Song 1: "Despacito (Remix)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Eenie Meenie" by Justin Bieber...
# Done.
# Searching for songs by Lupe Fiasco...
#
# Song 1: "Touch the Sky"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Battle Scars (with Guy Sebastian)" by Lupe Fiasco...
# Done.
# Searching for songs by David Guetta...
#
# Song 1: "2U"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Sexy Bitch (feat. Akon)" by David Guetta...
# Done.
# Searching for songs by K'NAAN...
#
# Changing artist name to 'K’naan'
# Song 1: "Immigrants (We Get the Job Done)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Wavin' Flag - Coca-Cola® Celebration Mix" by K’naan...
# Done.
# Searching for songs by K'NAAN...
#
# Changing artist name to 'K’naan'
# Song 1: "Immigrants (We Get the Job Done)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Take A Minute" by K’naan...
# Done.
# Searching for songs by David Guetta...
#
# Song 1: "2U"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Memories (feat. Kid Cudi)" by David Guetta...
# Done.
# Searching for songs by Diddy - Dirty Money...
#
# Changing artist name to 'Diddy – Dirty Money'
# Song 1: "Coming Home"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by David Guetta...
#
# Song 1: "2U"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "When Love Takes Over (feat. Kelly Rowland)" by David Guetta...
# Done.
# Searching for songs by Gotye...
#
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Teenage Dream" by Katy Perry...
# Done.
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Firework" by Katy Perry...
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Hot N Cold" by Katy Perry...
# Done.
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I Kissed A Girl" by Katy Perry...
# Searching for songs by Katy Perry...
#
# Song 1: "Feels"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Last Friday Night (T.G.I.F.)" by Katy Perry...
# Done.
# Searching for songs by T-Pain...
#
# Song 1: "The Real Her"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Best Love Song (feat. Chris Brown)" by T-Pain...
# Done.
# Searching for songs by T-Pain...
#
# Song 1: "The Real Her"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Bartender (feat. Akon)" by T-Pain...
# Done.
# Searching for songs by T-Pain...
#
# Song 1: "The Real Her"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I'm Sprung" by T-Pain...
# Done.
# Searching for songs by Rick Ross...
#
# Song 1: "Monster"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Maybach Music V (feat. DeJ Loaf)" by Rick Ross...
# Done.
# Searching for songs by Of Monsters and Men...
#
# Song 1: "Little Talks"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for songs by Gloria Gaynor...
#
# Song 1: "I Will Survive"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "I Will Survive - Single Version" by Gloria Gaynor...
# Done.
# Searching for songs by Usher...
#
# Song 1: "The Matrimony"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Confessions Part II" by Usher...
# Done.
# Searching for songs by Mike Posner...
#
# Song 1: "I Took a Pill in Ibiza"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Cooler Than Me - Single Mix" by Mike Posner...
# Done.
#                                     Name                       User  \
# 0    Wandered To LA (with Justin Bieber)                     Hassan
# 1                                   Doom                     Hassan
# 2                             Not Enough                     Hassan
# 3   Girl Of My Dreams (with SUGA of BTS)                     Hassan
# 4                                wannabe                     Hassan
# ..                                   ...                        ...
# 87      Maybach Music V (feat. DeJ Loaf)  qk6itwwnf6xczuzqyl2l3n5hc
# 88                          Little Talks  qk6itwwnf6xczuzqyl2l3n5hc
# 89       I Will Survive - Single Version  qk6itwwnf6xczuzqyl2l3n5hc
# 90                   Confessions Part II  qk6itwwnf6xczuzqyl2l3n5hc
# 91           Cooler Than Me - Single Mix  qk6itwwnf6xczuzqyl2l3n5hc
#
#                          Artist        Playlist             Playlist ID  \
# 0   [Juice WRLD, Justin Bieber]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 1                  [Juice WRLD]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 2                  [Juice WRLD]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 3       [Juice WRLD, SUGA, BTS]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 4                 [renforshort]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# ..                          ...             ...                     ...
# 87        [Rick Ross, DeJ Loaf]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 88        [Of Monsters and Men]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 89              [Gloria Gaynor]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 90                      [Usher]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 91  [Mike Posner, Matt Masurka]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
#
#                                                Lyrics
# 0   Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 1   Doom Lyrics[Intro]\n(D-D-Daytrip took it to te...
# 2   Not Enough Lyrics[Intro]\nShe said it's not en...
# 3   Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 4   ​wannabe Lyrics[Verse 1]\nAll you wanna do is ...
# ..                                                ...
# 87  Maybach Music V Lyrics[Intro]\nWhat is this?\n...
# 88  Little Talks Lyrics[Refrain: Nanna Bryndís Hil...
# 89  I Will Survive (Single Version) Lyrics[Intro]\...
# 90  Confessions Part II Lyrics[Intro]\nWatch this\...
# 91  Cooler Than Me (Single Mix) Lyrics[Chorus]\nIf...
#
# [245 rows x 6 columns]

# %%
all_my_songs.isnull().sum()
# Out:
# Name            0
# User            0
# Artist          0
# Playlist        0
# Playlist ID     0
# Lyrics         16
# dtype: int64

# %%
all_my_songs.dropna(subset='Lyrics', inplace=True)
all_my_songs
# Out:
#                                     Name                       User  \
# 0    Wandered To LA (with Justin Bieber)                     Hassan
# 1                                   Doom                     Hassan
# 2                             Not Enough                     Hassan
# 3   Girl Of My Dreams (with SUGA of BTS)                     Hassan
# 4                                wannabe                     Hassan
# ..                                   ...                        ...
# 87      Maybach Music V (feat. DeJ Loaf)  qk6itwwnf6xczuzqyl2l3n5hc
# 88                          Little Talks  qk6itwwnf6xczuzqyl2l3n5hc
# 89       I Will Survive - Single Version  qk6itwwnf6xczuzqyl2l3n5hc
# 90                   Confessions Part II  qk6itwwnf6xczuzqyl2l3n5hc
# 91           Cooler Than Me - Single Mix  qk6itwwnf6xczuzqyl2l3n5hc
#
#                          Artist        Playlist             Playlist ID  \
# 0   [Juice WRLD, Justin Bieber]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 1                  [Juice WRLD]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 2                  [Juice WRLD]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 3       [Juice WRLD, SUGA, BTS]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 4                 [renforshort]  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# ..                          ...             ...                     ...
# 87        [Rick Ross, DeJ Loaf]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 88        [Of Monsters and Men]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 89              [Gloria Gaynor]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 90                      [Usher]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 91  [Mike Posner, Matt Masurka]       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
#
#                                                Lyrics
# 0   Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 1   Doom Lyrics[Intro]\n(D-D-Daytrip took it to te...
# 2   Not Enough Lyrics[Intro]\nShe said it's not en...
# 3   Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 4   ​wannabe Lyrics[Verse 1]\nAll you wanna do is ...
# ..                                                ...
# 87  Maybach Music V Lyrics[Intro]\nWhat is this?\n...
# 88  Little Talks Lyrics[Refrain: Nanna Bryndís Hil...
# 89  I Will Survive (Single Version) Lyrics[Intro]\...
# 90  Confessions Part II Lyrics[Intro]\nWatch this\...
# 91  Cooler Than Me (Single Mix) Lyrics[Chorus]\nIf...
#
# [229 rows x 6 columns]

# %%
all_my_songs.to_csv("allmysongs.csv", index=False)

# %%
pwd
# Out:
# 'C:\\Users\\HFaro\\OneDrive\\Desktop\\Ironhack\\Projects\\Project-4-APIs'

# %%
import pandas as pd
import sqlalchemy as alch
from getpass import getpass
import re

# %%
df = pd.read_csv("data/allmysongs.csv")

# %%
load_dotenv()
# Out:
# True

# %%
pw = os.getenv("sql_pw")

# %%
db = "spotify"

# %%
connectionData = f"mysql+pymysql://root:{pw}@localhost/{db}"

# %%
engine = alch.create_engine(connectionData ,pool_size=10, max_overflow=20)

# %%
#df.to_sql("spotify", con=engine)

# %%
df.to_sql(name="spotify",if_exists='append',con = engine)
# Out:
# 229

# %%
def remove_brackets (string):

#this will remove any brackets in the lyrics

    if type(string) == str:
        pattern = "\[[A-Za-z\s\d]+\]"
        bracketless_string = re.sub(pattern, "", string) 
        return bracketless_string
    else:
        pass

# %%
df["Lyrics"] = df.Lyrics.apply(remove_brackets)
df.sample()
df["Artist"] = df.Artist.apply(remove_brackets)
df.sample()
# Out:
#                   Name    User   Artist        Playlist  \
# 30  god of the sunsets  Hassan  ['SEB']  straight vibin
#
#                Playlist ID                                             Lyrics
# 30  62aap5B2EcMMcQ3DWNoB6L  Arabian Nights,Vol. 2 (Chap. 3) LyricsTale of ...

# %%
def quoting (string):
    if type(string) == string:
        string = string.replace('"', "`")
        string = string.replace("'", "`")
        return string

    elif type(string) == list:
        for i in string:
            i = i.replace('"', "`")
            i = i.replace("'", "`")
        return i
    else:
        return string

# %%
df["Artist"] = df["Artist"].apply(quoting)
df["Lyrics"] = df["Lyrics"].apply(quoting)
df["Name"] = df["Name"].apply(lambda x: x.replace('"', "`"))
df
# Out:
#                                      Name                       User  \
# 0     Wandered To LA (with Justin Bieber)                     Hassan
# 1                                    Doom                     Hassan
# 2                              Not Enough                     Hassan
# 3    Girl Of My Dreams (with SUGA of BTS)                     Hassan
# 4                                 wannabe                     Hassan
# ..                                    ...                        ...
# 224      Maybach Music V (feat. DeJ Loaf)  qk6itwwnf6xczuzqyl2l3n5hc
# 225                          Little Talks  qk6itwwnf6xczuzqyl2l3n5hc
# 226       I Will Survive - Single Version  qk6itwwnf6xczuzqyl2l3n5hc
# 227                   Confessions Part II  qk6itwwnf6xczuzqyl2l3n5hc
# 228           Cooler Than Me - Single Mix  qk6itwwnf6xczuzqyl2l3n5hc
#
#                               Artist        Playlist             Playlist ID  \
# 0    ['Juice WRLD', 'Justin Bieber']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 1                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 2                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 3      ['Juice WRLD', 'SUGA', 'BTS']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 4                    ['renforshort']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# ..                               ...             ...                     ...
# 224        ['Rick Ross', 'DeJ Loaf']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 225          ['Of Monsters and Men']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 226                ['Gloria Gaynor']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 227                        ['Usher']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 228  ['Mike Posner', 'Matt Masurka']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
#
#                                                 Lyrics
# 0    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 1    Doom Lyrics\n(D-D-Daytrip took it to ten, hey)...
# 2    Not Enough Lyrics\nShe said it's not enough\nO...
# 3    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 4    ​wannabe Lyrics\nAll you wanna do is cocaine\n...
# ..                                                 ...
# 224  Maybach Music V Lyrics\nWhat is this?\nMaybach...
# 225  Little Talks Lyrics[Refrain: Nanna Bryndís Hil...
# 226  I Will Survive (Single Version) Lyrics\nAt fir...
# 227  Confessions Part II Lyrics\nWatch this\n\n\nTh...
# 228  Cooler Than Me (Single Mix) Lyrics\nIf I could...
#
# [229 rows x 6 columns]

# %%
doom = df.iloc[1]["Lyrics"]
doom
# Out:
# "Doom Lyrics\n(D-D-Daytrip took it to ten, hey)\n\n\nNo, I can't be fooled\nI ain't playing by your rules\nI'm\u2005known\u2005to lose my\u2005cool, but that's cool\n'Cause I'm known\u2005to be too cool\nThere's a room full of toxic people, but it feels like it's just me and her in the room\nI'd rather me die before she, so I mix drugs up tryna find my doom\nTryna find my doom, doom, doom\nTryna find my doom\nTryna find my doom, doom, doom, doom\n\nI have a lot of troubles\nI admit I'm running from 'em\nWalking through Hollywood\nI admit, I'm astonished\nSo much has happened in the last few months\nFrom broke to rich to finding love again\nI said so much has happened in the last three months\nMore drugs to mix, so high I don't pick up the phone no mo'\nNew phone, who is this? Uh-oh\nYou got some nerve, dumb ho\nWhere were you before\nI could pay your mortgage?\nNow all my shoes cost your car\nKarma's a ugly broad\nYeah, she'll leave her scars\n\n\nNo, I can't be fooled\nI ain't playing by your rules\nI'm known to lose my cool, but that's cool\n'Cause I'm known to be too cool\nThere's a room full of toxic people, but it feels like it's just me and her in the room\nI'd rather me die before she, so I mix drugs up tryna find my doom\nTryna find my doom, doom, doom\nTryna find my doom\nTryna find my doom, doom, doom, doom\n\nTryna find my tomb, ended up finding you\nI assumed that you were gonna leave me overconsumed\nConsumed, consumed, consumed\nYeah, I'm fucked up, yeah, but you already knew\nWhat's your favorite color besides blue? You're always blue\nYou always been the one for me, you knew that too\nUh, fucked up, drunk driving on the avenue\nWrist hanging out the window, let the Rollie do what it do\nKeep a all black four-nickel on me too\n\n\nFucked up, drunk driving on the avenue\nWrist hanging out the window, let the Rollie do what it do\nKeep a all black four-nickel on me too, on me too\n\n\nNo, I can't be fooled\nI ain't playing by your rules\nI'm known to lose my cool, but that's cool\n'Cause I'm known to be too cool\nThere's a room full of toxic people, but it feels like it's just me and her in the room\nI'd rather me die before she, so I mix drugs up tryna find my doom\nTryna find my doom, doom, doom (D-D-Daytrip took it to ten, hey)\nTryna find my doom\nTryna find my doom, doom, doom, doom36Embed"

# %%
def tokenizer(txt):
    try:
        if detect(txt) == "en":
            nlp = spacy.load("en_core_web_sm")   #The languages I will be analyzing as per the playlists added.
        else:
            return "Lyrics are not English"
    except:
        return np.nan
    
    tokens = nlp(txt)
    filtered = []
    
    
    for token in tokens:
        if not token.is_stop:
            lemma = token.lemma_.lower().strip()
            if re.search('^[a-zA-Z]+$',lemma): # This will remove the question marks
                filtered.append(lemma)
    return " ".join(filtered)

# %%
df["Tokenized Lyrics"] = df["Lyrics"].apply(tokenizer)

# %%
df.isnull().sum()

# %%
df.dropna(subset='Lyrics', inplace=True)
df

# %%
doom = df.iloc[1]["Tokenized Lyrics"]
doom

# %%
wordcloud = WordCloud(width=1600,height=400).generate(" ".join(set(doom.split(" "))))
plt.figure(figsize=(15,10), facecolor="k")
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
#plt.savefig('images/wordcloud.png', facecolor='k', bbox_inches='tight')
plt.show();

# %%
def sa (x):
    sia = SentimentIntensityAnalyzer()
    try:
        return sia.polarity_scores(x)
    except:
        return x

# %%
sa(doom)

# %%
df["Sentiment Score"] = df["Tokenized Lyrics"].apply(sa)

# %%
df.describe()
# Out:
#                      Name    User    Artist   Playlist  \
# count                 229     229       229        229
# unique                228       2       178          5
# top     Party Rock Anthem  Hassan  ['Lund']  Nostalgia
# freq                    2     150         7         79
#
#                    Playlist ID  \
# count                      229
# unique                       5
# top     0WrD7hV1xnhqiPhNXNYWU3
# freq                        79
#
#                                                    Lyrics  \
# count                                                 229
# unique                                                221
# top     Chris Brown Videography Lyrics2005Whose Girl I...
# freq                                                    6
#
#                                          Tokenized Lyrics  \
# count                                                 229
# unique                                                219
# top     chris brown videography girl run feat juelz sa...
# freq                                                    6
#
#                                           Sentiment Score
# count                                                 229
# unique                                                219
# top     {'neg': 0.093, 'neu': 0.783, 'pos': 0.124, 'co...
# freq                                                    6

# %%
df["Sentiment Score"][1]
# Out:
# {'neg': 0.408, 'neu': 0.415, 'pos': 0.177, 'compound': -0.9969}

# %%
df
# Out:
#                                      Name                       User  \
# 0     Wandered To LA (with Justin Bieber)                     Hassan
# 1                                    Doom                     Hassan
# 2                              Not Enough                     Hassan
# 3    Girl Of My Dreams (with SUGA of BTS)                     Hassan
# 4                                 wannabe                     Hassan
# ..                                    ...                        ...
# 224      Maybach Music V (feat. DeJ Loaf)  qk6itwwnf6xczuzqyl2l3n5hc
# 225                          Little Talks  qk6itwwnf6xczuzqyl2l3n5hc
# 226       I Will Survive - Single Version  qk6itwwnf6xczuzqyl2l3n5hc
# 227                   Confessions Part II  qk6itwwnf6xczuzqyl2l3n5hc
# 228           Cooler Than Me - Single Mix  qk6itwwnf6xczuzqyl2l3n5hc
#
#                               Artist        Playlist             Playlist ID  \
# 0    ['Juice WRLD', 'Justin Bieber']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 1                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 2                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 3      ['Juice WRLD', 'SUGA', 'BTS']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 4                    ['renforshort']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# ..                               ...             ...                     ...
# 224        ['Rick Ross', 'DeJ Loaf']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 225          ['Of Monsters and Men']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 226                ['Gloria Gaynor']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 227                        ['Usher']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 228  ['Mike Posner', 'Matt Masurka']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
#
#                                                 Lyrics  \
# 0    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 1    Doom Lyrics\n(D-D-Daytrip took it to ten, hey)...
# 2    Not Enough Lyrics\nShe said it's not enough\nO...
# 3    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 4    ​wannabe Lyrics\nAll you wanna do is cocaine\n...
# ..                                                 ...
# 224  Maybach Music V Lyrics\nWhat is this?\nMaybach...
# 225  Little Talks Lyrics[Refrain: Nanna Bryndís Hil...
# 226  I Will Survive (Single Version) Lyrics\nAt fir...
# 227  Confessions Part II Lyrics\nWatch this\n\n\nTh...
# 228  Cooler Than Me (Single Mix) Lyrics\nIf I could...
#
#                                       Tokenized Lyrics  \
# 0    today hits feat kid laroi justin bieber gayle ...
# 1    doom lyrics d d daytrip take hey fool ai play ...
# 2    lyrics say oh oh oh uh drownin liquor bottle d...
# 3    today hits feat kid laroi justin bieber gayle ...
# 4    lyrics wanna cocaine play guitar think cobain ...
# ..                                                 ...
# 224  maybach music v lyrics maybach music like mayb...
# 225  little talks nanna ragnar hey hey hey verse na...
# 226  survive single version lyric afraid petrify ke...
# 227  confession ii lyrics watch confession think sa...
# 228  cool single mix lyric write song fall love arm...
#
#                                        Sentiment Score
# 0    {'neg': 0.102, 'neu': 0.735, 'pos': 0.163, 'co...
# 1    {'neg': 0.408, 'neu': 0.415, 'pos': 0.177, 'co...
# 2    {'neg': 0.166, 'neu': 0.439, 'pos': 0.395, 'co...
# 3    {'neg': 0.102, 'neu': 0.735, 'pos': 0.163, 'co...
# 4    {'neg': 0.222, 'neu': 0.615, 'pos': 0.163, 'co...
# ..                                                 ...
# 224  {'neg': 0.154, 'neu': 0.647, 'pos': 0.2, 'comp...
# 225  {'neg': 0.107, 'neu': 0.643, 'pos': 0.25, 'com...
# 226  {'neg': 0.177, 'neu': 0.55, 'pos': 0.273, 'com...
# 227  {'neg': 0.131, 'neu': 0.759, 'pos': 0.11, 'com...
# 228  {'neg': 0.095, 'neu': 0.539, 'pos': 0.365, 'co...
#
# [229 rows x 8 columns]

# %%
#df.to_csv("allmysongs.csv", index=False)
df
# Out:
#                                      Name                       User  \
# 0     Wandered To LA (with Justin Bieber)                     Hassan
# 1                                    Doom                     Hassan
# 2                              Not Enough                     Hassan
# 3    Girl Of My Dreams (with SUGA of BTS)                     Hassan
# 4                                 wannabe                     Hassan
# ..                                    ...                        ...
# 224      Maybach Music V (feat. DeJ Loaf)  qk6itwwnf6xczuzqyl2l3n5hc
# 225                          Little Talks  qk6itwwnf6xczuzqyl2l3n5hc
# 226       I Will Survive - Single Version  qk6itwwnf6xczuzqyl2l3n5hc
# 227                   Confessions Part II  qk6itwwnf6xczuzqyl2l3n5hc
# 228           Cooler Than Me - Single Mix  qk6itwwnf6xczuzqyl2l3n5hc
#
#                               Artist        Playlist             Playlist ID  \
# 0    ['Juice WRLD', 'Justin Bieber']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 1                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 2                     ['Juice WRLD']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 3      ['Juice WRLD', 'SUGA', 'BTS']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# 4                    ['renforshort']  straight vibin  62aap5B2EcMMcQ3DWNoB6L
# ..                               ...             ...                     ...
# 224        ['Rick Ross', 'DeJ Loaf']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 225          ['Of Monsters and Men']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 226                ['Gloria Gaynor']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 227                        ['Usher']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
# 228  ['Mike Posner', 'Matt Masurka']       Nostalgia  0WrD7hV1xnhqiPhNXNYWU3
#
#                                                 Lyrics
# 0    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 1    Doom Lyrics[Intro]\n(D-D-Daytrip took it to te...
# 2    Not Enough Lyrics[Intro]\nShe said it's not en...
# 3    Today’s Top Hits 12/17/21 (feat. The Kid LAROI...
# 4    ​wannabe Lyrics[Verse 1]\nAll you wanna do is ...
# ..                                                 ...
# 224  Maybach Music V Lyrics[Intro]\nWhat is this?\n...
# 225  Little Talks Lyrics[Refrain: Nanna Bryndís Hil...
# 226  I Will Survive (Single Version) Lyrics[Intro]\...
# 227  Confessions Part II Lyrics[Intro]\nWatch this\...
# 228  Cooler Than Me (Single Mix) Lyrics[Chorus]\nIf...
#
# [229 rows x 6 columns]

# %%
df.iloc[2]["Sentiment Score"]
# Out:
# {'neu': 0.439, 'compound': 0.9953}

# %%
for i in df["Sentiment Score"]:
    
    i.pop('neg','pos')
    i.pop('neu')
    
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 for i in df["Sentiment Score"]:
#       2     print(i)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
straight_vibin_score = []
for i in df[df["Playlist"]=="straight vibin"]["Sentiment Score"]:
    straight_vibin_score.append(i["compound"])
st.mean(straight_vibin_score)
# Out:
# 0.36505853658536586

# %%
dysphoria_score = []
for i in df[df["Playlist"]=="Dysphoria "]["Sentiment Score"]:
    dysphoria_score.append(i["compound"])
st.mean(dysphoria_score)
# Out:
# 0.051548936170212764

# %%
stink_score = []
for i in df[df["Playlist"]=="stink"]["Sentiment Score"]:
    stink_score.append(i["compound"])
st.mean(stink_score)
# Out:
# 0.5136999999999999

# %%
nostalgia_score = []
for i in df[df["Playlist"]=="Nostalgia"]["Sentiment Score"]:
    nostalgia_score.append(i["compound"])
st.mean(nostalgia_score)
# Out:
# 0.5358119565217391

# %%
mmmm_score = []
for i in df[df["Playlist"]=="mmmm"]["Sentiment Score"]:
    mmmm_score.append(i["compound"])
st.mean(mmmm_score)
# Out:
# -0.0009295454545454493

# %%
len(straight_vibin_score)
# Out:
# 41

# %%
len(mmmm_score)
# Out:
# 44

# %%
len(stink_score)
# Out:
# 21

# %%
len(nostalgia_score)
# Out:
# 92

# %%
len(dysphoria_score)
# Out:
# 47

# %%
sad = mmmm_score[0:21]
sad
# Out:
# [-0.9744,
#  -0.8987,
#  -0.9896,
#  -0.9982,
#  0.9186,
#  0.9968,
#  -0.9571,
#  -0.9578,
#  0.3612,
#  -0.9136,
#  0.9583,
#  -0.8625,
#  -0.6908,
#  -0.9468,
#  0.25,
#  -0.9984,
#  -0.9883,
#  0.872,
#  -0.9913,
#  -0.9769,
#  -0.9638]

# %%
happy = dysphoria_score[0:21]

# %%
chill = straight_vibin_score[10:31]

# %%
nostalgia = nostalgia_score[:21]

# %%
motivation = stink_score[:21]

# %%
svg = pd.DataFrame(chill)
svg
# Out:
#          0
# 0   0.8750
# 1   0.2960
# 2  -0.8402
# 3   0.9633
# 4  -0.9595
# 5   0.9833
# 6  -0.9955
# 7   0.9969
# 8   0.9836
# 9  -0.9975
# 10  0.9904
# 11  0.4404
# 12  0.9902
# 13  0.9403
# 14  0.9985
# 15 -0.9982
# 16 -0.9821
# 17 -0.4767
# 18 -0.9935
# 19 -0.8481
# 20  1.0000

# %%
svg.describe()
# Out:
#                0
# count  21.000000
# mean    0.112695
# std     0.921581
# min    -0.998200
# 25%    -0.959500
# 50%     0.440400
# 75%     0.983600
# max     1.000000

# %%
svg['happy'] = happy

# %%
svg['nostalgia'] = nostalgia

# %%
svg['motivation'] = motivation

# %%
svg['sad'] = sad

# %%
svg = svg.rename(columns={0: 'chill'})

# %%
svg
# Out:
#      chill   happy  nostalgia  motivation     sad
# 0   0.8750  0.9881    -0.2335     -0.6124 -0.9744
# 1   0.2960 -0.9622     0.4588      0.9943 -0.8987
# 2  -0.8402 -0.9766     0.9979      0.9974 -0.9896
# 3   0.9633 -0.9971    -0.9561      0.9618 -0.9982
# 4  -0.9595  0.9001     0.8434     -0.9623  0.9186
# 5   0.9833  0.8020    -0.8807     -0.9976  0.9968
# 6  -0.9955 -0.9868     0.9979      0.0000 -0.9571
# 7   0.9969  0.5859    -0.7906      0.9931 -0.9578
# 8   0.9836  0.9790     0.9971      0.9729  0.3612
# 9  -0.9975 -0.9856     0.9986      0.9843 -0.9136
# 10  0.9904  0.9903    -0.9744     -0.3760  0.9583
# 11  0.4404 -0.4939     0.9894      0.9153 -0.8625
# 12  0.9902  0.9946     0.9982      0.9826 -0.6908
# 13  0.9403  0.7918     0.0000      0.9986 -0.9468
# 14  0.9985 -0.8316     0.9959      0.9001  0.2500
# 15 -0.9982 -0.9217     0.9300      0.9657 -0.9984
# 16 -0.9821  0.9814     0.9957      0.9982 -0.9883
# 17 -0.4767  0.9806     0.9903      0.9929  0.8720
# 18 -0.9935 -0.3818     0.9931      0.9980 -0.9913
# 19 -0.8481 -0.3214     0.9899     -0.9169 -0.9769
# 20  1.0000  0.9979     0.9970      0.9977 -0.9638

# %%
svg.describe()
# Out:
#            chill      happy  nostalgia  motivation        sad
# count  21.000000  21.000000  21.000000   21.000000  21.000000
# mean    0.112695   0.101571   0.492281    0.513700  -0.464348
# std     0.921581   0.891214   0.771323    0.776651   0.791803
# min    -0.998200  -0.997100  -0.974400   -0.997600  -0.998400
# 25%    -0.959500  -0.921700   0.000000    0.000000  -0.976900
# 50%     0.440400   0.585900   0.989900    0.972900  -0.946800
# 75%     0.983600   0.980600   0.997000    0.994300   0.250000
# max     1.000000   0.997900   0.998600    0.998600   0.996800

# %%
svg.to_csv("sentimentofplaylists.csv", index=False)

# %%
load_dotenv()

pw = os.getenv("sql_pw")

db = "spotify"

connectionData = f"mysql+pymysql://root:{pw}@localhost/{db}"

engine = alch.create_engine(connectionData ,pool_size=10, max_overflow=20)

#df.to_sql("spotify", con=engine)

svg.to_sql(name="sentiments",if_exists='append',con = engine)
# Out:
# 21

# %%
sns.kdeplot(x = chill, fill=True);

# %%
fig = sns.kdeplot(svg['chill'], shade=True, color="r")
fig = sns.kdeplot(svg['sad'], shade=True, color="b")
fig = sns.kdeplot(svg['happy'], shade=True, color="g")
fig = sns.kdeplot(svg['motivation'], shade=True, color="m")
fig = sns.kdeplot(svg['nostalgia'], shade=True, color="y")
plt.show()
plt.savefig("figure1.jpg")

# %%
plt.savefig("figure1.jpg")

# %%
fig1 = sns.histplot(data=svg, x="chill", color="red", label="chill", bins = 10,kde=True)
plt.show()

# %%
fig2 = sns.histplot(data=svg, x="sad", color="orange", label="sad", bins = 10, kde=True)

# %%
fig3 = sns.histplot(data=svg, x="happy", color="yellow", label="happy", bins = 10, kde=True)

# %%
fig4 = sns.histplot(data=svg, x="motivation", color="magenta", label="motivation", bins = 10,kde=True)

# %%
fig5 = sns.histplot(data=svg, x="nostalgia", color="blue", label="nostalgia", bins = 10, kde=True)

# %%
from flask import Flask, request, jsonify
from pymongo import MongoClient
import random
import tools.sqltools as sql
import markdown.extensions.fenced_code
import json
import os
import json
import random

# %%
playlist = stink

# %%
def get_playlist(playlist):
    query = (f"""SELECT * Playlist FROM spotify WHERE Playlist = "{playlist}";""")
    df=pd.read_sql_query(query,con=engine)
    return df.to_dict(orient='records')

# %%
get_playlist("stink")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~\anaconda3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1064, 'You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near \'Playlist FROM spotify WHERE Playlist = "stink"\' at line 1')
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [206], in <cell line: 1>()
# ----> 1 get_playlist("stink")
#
# Input In [195], in get_playlist(playlist)
#       1 def get_playlist(playlist):
#       2     query = (f"""SELECT * Playlist FROM spotify WHERE Playlist = "{playlist}";""")
# ----> 3     df=pd.read_sql_query(query,con=engine)
#       4     return df.to_dict(orient='records')
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3152, in Engine.execute(self, statement, *multiparams, **params)
#    3134 """Executes the given construct and returns a
#    3135 :class:`_engine.CursorResult`.
#    3136
#    (...)
#    3149
#    3150 """
#    3151 connection = self.connect(close_with_result=True)
# -> 3152 return connection.execute(statement, *multiparams, **params)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1280, in Connection.execute(self, statement, *multiparams, **params)
#    1271 if isinstance(statement, util.string_types):
#    1272     util.warn_deprecated_20(
#    1273         "Passing a string to Connection.execute() is "
#    1274         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1277         "driver-level SQL string."
#    1278     )
# -> 1280     return self._exec_driver_sql(
#    1281         statement,
#    1282         multiparams,
#    1283         params,
#    1284         _EMPTY_EXECUTION_OPTS,
#    1285         future=False,
#    1286     )
#    1288 try:
#    1289     meth = statement._execute_on_connection
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1584, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1574         (
#    1575             statement,
#    1576             distilled_params,
#    (...)
#    1580             statement, distilled_parameters, execution_options
#    1581         )
#    1583 dialect = self.dialect
# -> 1584 ret = self._execute_context(
#    1585     dialect,
#    1586     dialect.execution_ctx_cls._init_statement,
#    1587     statement,
#    1588     distilled_parameters,
#    1589     execution_options,
#    1590     statement,
#    1591     distilled_parameters,
#    1592 )
#    1594 if not future:
#    1595     if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1848             branched.close()
#    1850 except BaseException as e:
# -> 1851     self._handle_dbapi_exception(
#    1852         e, statement, parameters, cursor, context
#    1853     )
#    1855 return result
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2030     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2031 elif should_wrap:
# -> 2032     util.raise_(
#    2033         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034     )
#    2035 else:
#    2036     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1806                 break
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#    1813     self.dispatch.after_cursor_execute(
#    1814         self,
#    1815         cursor,
#    (...)
#    1819         context.executemany,
#    1820     )
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~\anaconda3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, 'You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near \'Playlist FROM spotify WHERE Playlist = "stink"\' at line 1')
# [SQL: SELECT * Playlist FROM spotify WHERE Playlist = "stink";]
# (Background on this error at: https://sqlalche.me/e/14/f405)
